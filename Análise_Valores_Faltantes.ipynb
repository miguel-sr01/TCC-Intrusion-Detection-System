# %%
import pandas as pd
df_mon = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv',sep=',')
df_mon.columns = df_mon.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_mon.columns))
# Verificando a quantidade de registros nulos:
df_mon.isnull().sum()
len(df_mon.columns))
# Out:
# DestinationPort             0
# FlowDuration                0
# TotalFwdPackets             0
# TotalBackwardPackets        0
# TotalLengthofFwdPackets     0
# TotalLengthofBwdPackets     0
# FwdPacketLengthMax          0
# FwdPacketLengthMin          0
# FwdPacketLengthMean         0
# FwdPacketLengthStd          0
# BwdPacketLengthMax          0
# BwdPacketLengthMin          0
# BwdPacketLengthMean         0
# BwdPacketLengthStd          0
# FlowBytes/s                64
# FlowPackets/s               0
# FlowIATMean                 0
# FlowIATStd                  0
# FlowIATMax                  0
# FlowIATMin                  0
# FwdIATTotal                 0
# FwdIATMean                  0
# FwdIATStd                   0
# FwdIATMax                   0
# FwdIATMin                   0
# BwdIATTotal                 0
# BwdIATMean                  0
# BwdIATStd                   0
# BwdIATMax                   0
# BwdIATMin                   0
# FwdPSHFlags                 0
# ...

# %% [markdown]
# Quantidade de registros nulos para segunda:
#
# FlowBytes/s                64

# %%
import pandas as pd
df_tues = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv',sep=',')
df_tues.columns = df_tues.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_tues.columns))
# Verificando a quantidade de registros nulos:
df_tues.isnull().sum()
# Out:
# DestinationPort              0
# FlowDuration                 0
# TotalFwdPackets              0
# TotalBackwardPackets         0
# TotalLengthofFwdPackets      0
# TotalLengthofBwdPackets      0
# FwdPacketLengthMax           0
# FwdPacketLengthMin           0
# FwdPacketLengthMean          0
# FwdPacketLengthStd           0
# BwdPacketLengthMax           0
# BwdPacketLengthMin           0
# BwdPacketLengthMean          0
# BwdPacketLengthStd           0
# FlowBytes/s                201
# FlowPackets/s                0
# FlowIATMean                  0
# FlowIATStd                   0
# FlowIATMax                   0
# FlowIATMin                   0
# FwdIATTotal                  0
# FwdIATMean                   0
# FwdIATStd                    0
# FwdIATMax                    0
# FwdIATMin                    0
# BwdIATTotal                  0
# BwdIATMean                   0
# BwdIATStd                    0
# BwdIATMax                    0
# BwdIATMin                    0
# ...

# %% [markdown]
# Quantidade de registros nulos para terça:
#
# FlowBytes/s                201

# %%
import pandas as pd
df_wed = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv',sep=',')
df_wed.columns = df_wed.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_wed.columns))
# Verificando a quantidade de registros nulos:
df_wed.isnull().sum()
# Out:
# DestinationPort               0
# FlowDuration                  0
# TotalFwdPackets               0
# TotalBackwardPackets          0
# TotalLengthofFwdPackets       0
# TotalLengthofBwdPackets       0
# FwdPacketLengthMax            0
# FwdPacketLengthMin            0
# FwdPacketLengthMean           0
# FwdPacketLengthStd            0
# BwdPacketLengthMax            0
# BwdPacketLengthMin            0
# BwdPacketLengthMean           0
# BwdPacketLengthStd            0
# FlowBytes/s                1008
# FlowPackets/s                 0
# FlowIATMean                   0
# FlowIATStd                    0
# FlowIATMax                    0
# FlowIATMin                    0
# FwdIATTotal                   0
# FwdIATMean                    0
# FwdIATStd                     0
# FwdIATMax                     0
# FwdIATMin                     0
# BwdIATTotal                   0
# BwdIATMean                    0
# BwdIATStd                     0
# BwdIATMax                     0
# ...

# %% [markdown]
# Quantidade de registros nulos para quarta:
#
# FlowBytes/s                1008

# %%
import pandas as pd
df_thurs1 = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv',sep=',')
df_thurs1.columns = df_thurs1.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_thurs1.columns))
# Verificando a quantidade de registros nulos:
df_thurs1.isnull().sum()
# Out:
# DestinationPort             0
# FlowDuration                0
# TotalFwdPackets             0
# TotalBackwardPackets        0
# TotalLengthofFwdPackets     0
# TotalLengthofBwdPackets     0
# FwdPacketLengthMax          0
# FwdPacketLengthMin          0
# FwdPacketLengthMean         0
# FwdPacketLengthStd          0
# BwdPacketLengthMax          0
# BwdPacketLengthMin          0
# BwdPacketLengthMean         0
# BwdPacketLengthStd          0
# FlowBytes/s                20
# FlowPackets/s               0
# FlowIATMean                 0
# FlowIATStd                  0
# FlowIATMax                  0
# FlowIATMin                  0
# FwdIATTotal                 0
# FwdIATMean                  0
# FwdIATStd                   0
# FwdIATMax                   0
# FwdIATMin                   0
# BwdIATTotal                 0
# BwdIATMean                  0
# BwdIATStd                   0
# BwdIATMax                   0
# BwdIATMin                   0
# FwdPSHFlags                 0
# ...

# %% [markdown]
# Quantidade de registros nulos para quinta de manhã:
#
# FlowBytes/s                20

# %%
import pandas as pd
df_thurs2 = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv',sep=',')
df_thurs2.columns = df_thurs2.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_thurs2.columns))
# Verificando a quantidade de registros nulos:
df_thurs2.isnull().sum()
# Out:
# DestinationPort             0
# FlowDuration                0
# TotalFwdPackets             0
# TotalBackwardPackets        0
# TotalLengthofFwdPackets     0
# TotalLengthofBwdPackets     0
# FwdPacketLengthMax          0
# FwdPacketLengthMin          0
# FwdPacketLengthMean         0
# FwdPacketLengthStd          0
# BwdPacketLengthMax          0
# BwdPacketLengthMin          0
# BwdPacketLengthMean         0
# BwdPacketLengthStd          0
# FlowBytes/s                18
# FlowPackets/s               0
# FlowIATMean                 0
# FlowIATStd                  0
# FlowIATMax                  0
# FlowIATMin                  0
# FwdIATTotal                 0
# FwdIATMean                  0
# FwdIATStd                   0
# FwdIATMax                   0
# FwdIATMin                   0
# BwdIATTotal                 0
# BwdIATMean                  0
# BwdIATStd                   0
# BwdIATMax                   0
# BwdIATMin                   0
# FwdPSHFlags                 0
# ...

# %% [markdown]
# Quantidade de registros nulos para quinta de tarde:
#
# FlowBytes/s                18

# %%
import pandas as pd
df_fri1 = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv',sep=',')
df_fri1.columns = df_fri1.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_fri1.columns))
# Verificando a quantidade de registros nulos:
df_fri1.isnull().sum()
# Out:
# DestinationPort             0
# FlowDuration                0
# TotalFwdPackets             0
# TotalBackwardPackets        0
# TotalLengthofFwdPackets     0
# TotalLengthofBwdPackets     0
# FwdPacketLengthMax          0
# FwdPacketLengthMin          0
# FwdPacketLengthMean         0
# FwdPacketLengthStd          0
# BwdPacketLengthMax          0
# BwdPacketLengthMin          0
# BwdPacketLengthMean         0
# BwdPacketLengthStd          0
# FlowBytes/s                28
# FlowPackets/s               0
# FlowIATMean                 0
# FlowIATStd                  0
# FlowIATMax                  0
# FlowIATMin                  0
# FwdIATTotal                 0
# FwdIATMean                  0
# FwdIATStd                   0
# FwdIATMax                   0
# FwdIATMin                   0
# BwdIATTotal                 0
# BwdIATMean                  0
# BwdIATStd                   0
# BwdIATMax                   0
# BwdIATMin                   0
# FwdPSHFlags                 0
# ...

# %% [markdown]
# Quantidade de registros nulos para sexta de manhã:
#
# FlowBytes/s                28

# %%
import pandas as pd
df_fri2 = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv',sep=',')
df_fri2.columns = df_fri2.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_fri2.columns))
# Verificando a quantidade de registros nulos:
df_fri2.isnull().sum()
# Out:
# DestinationPort             0
# FlowDuration                0
# TotalFwdPackets             0
# TotalBackwardPackets        0
# TotalLengthofFwdPackets     0
# TotalLengthofBwdPackets     0
# FwdPacketLengthMax          0
# FwdPacketLengthMin          0
# FwdPacketLengthMean         0
# FwdPacketLengthStd          0
# BwdPacketLengthMax          0
# BwdPacketLengthMin          0
# BwdPacketLengthMean         0
# BwdPacketLengthStd          0
# FlowBytes/s                15
# FlowPackets/s               0
# FlowIATMean                 0
# FlowIATStd                  0
# FlowIATMax                  0
# FlowIATMin                  0
# FwdIATTotal                 0
# FwdIATMean                  0
# FwdIATStd                   0
# FwdIATMax                   0
# FwdIATMin                   0
# BwdIATTotal                 0
# BwdIATMean                  0
# BwdIATStd                   0
# BwdIATMax                   0
# BwdIATMin                   0
# FwdPSHFlags                 0
# ...

# %% [markdown]
# Quantidade de registros nulos para sexta PortScan:
#
# FlowBytes/s                15

# %%
import pandas as pd
df_fri3 = pd.read_csv('MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv',sep=',')
df_fri3.columns = df_fri3.columns.str.replace(' ', '')
pd.set_option('display.max_rows', len(df_fri3.columns))
# Verificando a quantidade de registros nulos:
df_fri3.isnull().sum()
# Out:
# DestinationPort            0
# FlowDuration               0
# TotalFwdPackets            0
# TotalBackwardPackets       0
# TotalLengthofFwdPackets    0
# TotalLengthofBwdPackets    0
# FwdPacketLengthMax         0
# FwdPacketLengthMin         0
# FwdPacketLengthMean        0
# FwdPacketLengthStd         0
# BwdPacketLengthMax         0
# BwdPacketLengthMin         0
# BwdPacketLengthMean        0
# BwdPacketLengthStd         1
# FlowBytes/s                4
# FlowPackets/s              1
# FlowIATMean                1
# FlowIATStd                 1
# FlowIATMax                 1
# FlowIATMin                 1
# FwdIATTotal                1
# FwdIATMean                 1
# FwdIATStd                  1
# FwdIATMax                  1
# FwdIATMin                  1
# BwdIATTotal                1
# BwdIATMean                 1
# BwdIATStd                  1
# BwdIATMax                  1
# BwdIATMin                  1
# FwdPSHFlags                1
# BwdPSHFlags                1
# ...

# %% [markdown]
# Quantidade de registros nulos para sexta DDOS:
#
# BwdPacketLengthStd         1
# FlowBytes/s                4
# FlowPackets/s              1
# FlowIATMean                1
# FlowIATStd                 1
# FlowIATMax                 1
# FlowIATMin                 1
# FwdIATTotal                1
# FwdIATMean                 1
# FwdIATStd                  1
# FwdIATMax                  1
# FwdIATMin                  1
# BwdIATTotal                1
# BwdIATMean                 1
# BwdIATStd                  1
# BwdIATMax                  1
# BwdIATMin                  1
# FwdPSHFlags                1
# BwdPSHFlags                1
# FwdURGFlags                1
# BwdURGFlags                1
# FwdHeaderLength            1
# BwdHeaderLength            1
# FwdPackets/s               1
# BwdPackets/s               1
# MinPacketLength            1
# MaxPacketLength            1
# PacketLengthMean           1
# PacketLengthStd            1
# PacketLengthVariance       1
# FINFlagCount               1
# SYNFlagCount               1
# RSTFlagCount               1
# PSHFlagCount               1
# ACKFlagCount               1
# URGFlagCount               1
# CWEFlagCount               1
# ECEFlagCount               1
# Down/UpRatio               1
# AveragePacketSize          1
# AvgFwdSegmentSize          1
# AvgBwdSegmentSize          1
# FwdHeaderLength.1          1
# FwdAvgBytes/Bulk           1
# FwdAvgPackets/Bulk         1
# FwdAvgBulkRate             1
# BwdAvgBytes/Bulk           1
# BwdAvgPackets/Bulk         1
# BwdAvgBulkRate             1
# SubflowFwdPackets          1
# SubflowFwdBytes            1
# SubflowBwdPackets          1
# SubflowBwdBytes            1
# Init_Win_bytes_forward     1
# Init_Win_bytes_backward    1
# act_data_pkt_fwd           1
# min_seg_size_forward       1
# ActiveMean                 1
# ActiveStd                  1
# ActiveMax                  1
# ActiveMin                  1
# IdleMean                   1
# IdleStd                    1
# IdleMax                    1
# IdleMin                    1
# Label                      1
